# %%
import pandas as pd

# %%
df1=pd.read_excel('/content/AmazingMartSalesDetails.xlsx','OrderBreakdown')

df=pd.read_excel('/content/AmazingMartSalesDetails.xlsx','ListOfOrders')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4117 entries, 0 to 4116
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       4117 non-null   object
#  1   Order Date     4117 non-null   datetime64[ns]
#  2   Customer Name  4117 non-null   object
#  3   City           4117 non-null   object
#  4   Country        4117 non-null   object
#  5   Region         4117 non-null   object
#  6   Segment        4117 non-null   object
#  7   Ship Date      4117 non-null   datetime64[ns]
#  8   Ship Mode      4117 non-null   object
#  9   State          4117 non-null   object
#  10  lon            4117 non-null   float64
#  11  lat            4117 non-null   float64
# dtypes: datetime64[ns](2), float64(2), object(8)
# memory usage: 386.1+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8047 entries, 0 to 8046
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      8047 non-null   object
#  1   Product Name  8047 non-null   object
#  2   Discount      8047 non-null   float64
#  3   Sales         8047 non-null   int64
#  4   Profit        8047 non-null   int64
#  5   Quantity      8047 non-null   int64
#  6   Category      8047 non-null   object
#  7   Sub-Category  8047 non-null   object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 503.1+ KB

# %%
df1.head()
# Out:
#           Order ID                           Product Name  Discount  Sales  \
# 0  BN-2011-7407039            Enermax Note Cards, Premium       0.5     45
# 1  AZ-2011-9050313     Dania Corner Shelving, Traditional       0.0    854
# 2  AZ-2011-6674300  Binney & Smith Sketch Pad, Easy-Erase       0.0    140
# 3  BN-2011-2819714             Boston Markers, Easy-Erase       0.5     27
# 4  BN-2011-2819714            Eldon Folders, Single Width       0.5     17
#
#    Profit  Quantity         Category Sub-Category
# 0     -26         3  Office Supplies        Paper
# 1     290         7        Furniture    Bookcases
# 2      21         3  Office Supplies          Art
# 3     -22         2  Office Supplies          Art
# 4      -1         2  Office Supplies      Storage

# %%
df.head()
# Out:
#           Order ID Order Date     Customer Name        City         Country  \
# 0  BN-2011-7407039 2011-01-01        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313 2011-01-03    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300 2011-01-04  Devin Huddleston     Valence          France
# 3  BN-2011-2819714 2011-01-04       Mary Parker  Birmingham  United Kingdom
# 4   AZ-2011-617423 2011-01-05      Daniel Burke  Echirolles          France
#
#     Region      Segment  Ship Date     Ship Mode                 State  \
# 0    North  Home Office 2011-01-05  Economy Plus             Stockholm
# 1    North     Consumer 2011-01-07       Economy               England
# 2  Central     Consumer 2011-01-08       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate 2011-01-09       Economy               England
# 4  Central  Home Office 2011-01-07      Priority  Auvergne-Rhône-Alpes
#
#          lon        lat
# 0  18.068581  59.329324
# 1  -3.010113  53.645708
# ...

# %%
df.columns
df.shape
# Out:
# (4117, 12)

# %%
# merge to table
df=df.merge(df1,on='Order ID')

# %%
df
# Out:
#              Order ID Order Date        Customer Name        City  \
# 0     BN-2011-7407039 2011-01-01           Ruby Patel   Stockholm
# 1     AZ-2011-9050313 2011-01-03       Summer Hayward   Southport
# 2     AZ-2011-6674300 2011-01-04     Devin Huddleston     Valence
# 3     BN-2011-2819714 2011-01-04          Mary Parker  Birmingham
# 4     BN-2011-2819714 2011-01-04          Mary Parker  Birmingham
# ...               ...        ...                  ...         ...
# 8042  AZ-2014-1412225 2014-12-31          Leon Barnes   Worcester
# 8043  AZ-2014-7604524 2014-12-31  Rebecca Chamberlain     Hamburg
# 8044  BN-2014-4140795 2014-12-31      Daniel Hamilton   Eindhoven
# 8045  BN-2014-4140795 2014-12-31      Daniel Hamilton   Eindhoven
# 8046  BN-2014-4140795 2014-12-31      Daniel Hamilton   Eindhoven
#
#              Country   Region      Segment  Ship Date     Ship Mode  \
# 0             Sweden    North  Home Office 2011-01-05  Economy Plus
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'City', 'Country', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'lon', 'lat',
#        'Product Name', 'Discount', 'Sales', 'Profit', 'Quantity', 'Category',
#        'Sub-Category'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8047 entries, 0 to 8046
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       8047 non-null   object
#  1   Order Date     8047 non-null   datetime64[ns]
#  2   Customer Name  8047 non-null   object
#  3   City           8047 non-null   object
#  4   Country        8047 non-null   object
#  5   Region         8047 non-null   object
#  6   Segment        8047 non-null   object
#  7   Ship Date      8047 non-null   datetime64[ns]
#  8   Ship Mode      8047 non-null   object
#  9   State          8047 non-null   object
#  10  lon            8047 non-null   float64
#  11  lat            8047 non-null   float64
#  12  Product Name   8047 non-null   object
#  13  Discount       8047 non-null   float64
#  14  Sales          8047 non-null   int64
#  15  Profit         8047 non-null   int64
#  16  Quantity       8047 non-null   int64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=df.drop_duplicates()

# %%
# DataCleaning
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Customer Name    0
# City             0
# Country          0
# Region           0
# Segment          0
# Ship Date        0
# Ship Mode        0
# State            0
# lon              0
# lat              0
# Product Name     0
# Discount         0
# Sales            0
# Profit           0
# Quantity         0
# Category         0
# Sub-Category     0
# Year             0
# Month            0
# dtype: int64

# %%
# df = df.drop_duplicates(subset='Order ID', keep='first')

# %%
df.shape
# Out:
# (8045, 21)

# %%
# show data from tail
df.tail(10)
# Out:
#              Order ID Order Date        Customer Name        City  \
# 8037  BN-2014-8679573 2014-12-30       Dennis Conaway   The Hague
# 8038  AZ-2014-4217323 2014-12-31          Evie Morton        Caen
# 8039  AZ-2014-8174835 2014-12-31         Eloise Sykes   Bielefeld
# 8040   AZ-2014-766953 2014-12-31         Jose Gambino  Maidenhead
# 8041   AZ-2014-766953 2014-12-31         Jose Gambino  Maidenhead
# 8042  AZ-2014-1412225 2014-12-31          Leon Barnes   Worcester
# 8043  AZ-2014-7604524 2014-12-31  Rebecca Chamberlain     Hamburg
# 8044  BN-2014-4140795 2014-12-31      Daniel Hamilton   Eindhoven
# 8045  BN-2014-4140795 2014-12-31      Daniel Hamilton   Eindhoven
# 8046  BN-2014-4140795 2014-12-31      Daniel Hamilton   Eindhoven
#
#              Country   Region      Segment  Ship Date     Ship Mode  \
# 8037     Netherlands  Central     Consumer 2015-01-01      Priority
# 8038          France  Central     Consumer 2015-01-02  Economy Plus
# ...

# %%
df.iloc[[1,2,3,4]]
# Out:
#           Order ID Order Date     Customer Name        City         Country  \
# 1  AZ-2011-9050313 2011-01-03    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300 2011-01-04  Devin Huddleston     Valence          France
# 3  BN-2011-2819714 2011-01-04       Mary Parker  Birmingham  United Kingdom
# 4  BN-2011-2819714 2011-01-04       Mary Parker  Birmingham  United Kingdom
#
#     Region    Segment  Ship Date Ship Mode                 State  ...  \
# 1    North   Consumer 2011-01-07   Economy               England  ...
# 2  Central   Consumer 2011-01-08   Economy  Auvergne-Rhône-Alpes  ...
# 3    North  Corporate 2011-01-09   Economy               England  ...
# 4    North  Corporate 2011-01-09   Economy               England  ...
#
#          lat                           Product Name Discount  Sales  Profit  \
# 1  53.645708     Dania Corner Shelving, Traditional      0.0    854     290
# 2  44.933393  Binney & Smith Sketch Pad, Easy-Erase      0.0    140      21
# ...

# %%
# strip columns space

df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'City', 'Country', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'lon', 'lat',
#        'Product Name', 'Discount', 'Sales', 'Profit', 'Quantity', 'Category',
#        'Sub-Category', 'Year', 'Month'],
#       dtype='object')

# %%
# add new year and month column

df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
df['Year']
# Out:
# 0       2011
# 1       2011
# 2       2011
# 3       2011
# 4       2011
#         ...
# 8042    2014
# 8043    2014
# 8044    2014
# 8045    2014
# 8046    2014
# Name: Year, Length: 8045, dtype: int32

# %%
# Total Sales Performance
#1 row wise total order id sales
totalSales=(df['Sales'])+(df['Profit'])

# %%
totalSales
# Out:
# 0         19
# 1       1144
# 2        161
# 3          5
# 4         16
#         ...
# 8042     364
# 8043      40
# 8044      20
# 8045      17
# 8046      89
# Length: 8045, dtype: int64

# %%
df[['Sales','Profit']].sum()
# Out:
# Sales     2348361
# Profit     283202
# dtype: int64

# %%
# Top 10 Products by Sales

df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Product Name
# Nokia Smart Phone, Full Size                          30645
# Hamilton Beach Stove, Silver                          16890
# Cisco Smart Phone, Cordless                           14723
# Novimex Executive Leather Armchair, Red               13898
# Cisco Smart Phone, with Caller ID                     13215
# Rogers File Cart, Single Width                        12967
# Hoover Stove, Red                                     12677
# Apple Smart Phone, Full Size                          12555
# Office Star Executive Leather Armchair, Adjustable    11687
# Eldon File Cart, Single Width                         11233
# Name: Sales, dtype: int64

# %%
# Top Performing Cities
df.groupby('City')['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# City
# London       69230
# Berlin       52555
# Vienna       51844
# Madrid       44897
# Paris        42245
# Rome         28330
# Barcelona    27405
# Hamburg      23574
# Marseille    21677
# Turin        19829
# Name: Sales, dtype: int64

# %%
# Region-wise Sales Analysis

df.groupby('Region')['Sales'].sum().sort_values(ascending=False)
# Out:
# Region
# Central    1315216
# South       517166
# North       515979
# Name: Sales, dtype: int64

# %%
# Shipping Mode Performance
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Economy         4860
# Economy Plus    1590
# Priority        1169
# Immediate        426
# Name: count, dtype: int64

# %%
df['Month'] = df['Order Date'].dt.month

# %%
df.groupby('Month')['Sales'].sum()
# Out:
# Month
# 1     139157
# 2     123685
# 3     122875
# 4     132051
# 5     142461
# 6     271744
# 7     146159
# 8     303089
# 9     295289
# 10    121861
# 11    277239
# 12    272751
# Name: Sales, dtype: int64

# %%
df.groupby('Month')['Sales'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>

# %%
df['Category'].value_counts().plot(kind='pie',autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# Sales Growth Trend Analysis
df.groupby(['Year','Month'])['Sales'].sum()
# Out:
# Year  Month
# 2011  1         14335
#       2         21646
#       3         20567
#       4         21920
#       5         28955
#       6         48837
#       7         16635
#       8         47822
#       9         62455
#       10        15670
#       11        52567
#       12        62939
# 2012  1         30022
#       2         15304
#       3         41388
#       4         30771
#       5         34359
#       6         54760
#       7         38345
#       8         85074
#       9         61777
#       10        35686
#       11        55079
#       12        66278
# 2013  1         45698
#       2         47151
#       3         28876
#       4         30627
#       5         41260
#       6         86822
#       7         48720
#       8         63124
#       9         69732
#       10        29938
#       11        77746
#       12        60446
# 2014  1         49102
#       2         39584
#       3         32044
#       4         48733
#       5         37887
# ...

# %%
# Shipping Delay Analysis
df['Shipping Days'] = (df['Ship Date'] - df['Order Date']).dt.days
df['Shipping Days'].mean()
# Out:
# np.float64(4.0065879428216284)

# %%
df.to_csv('cleanAmazingMart.csv')
